# %% [markdown]
# Esercizio 1 — KMeans su dati artificiali
#
# Usando make_blobs, completare il codice in modo da:
#
# generare 2000 punti distribuiti in 5 blob;
# applicare KMeans con 5 cluster;
# ottenere le label assegnate ai punti;
# visualizzare i centroidi;
# predire il cluster di nuovi punti;
# calcolare la distanza dei nuovi punti da ogni centroide tramite transform;
# stampare l’inerzia.
# # ESERCIZIO 1
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# from sklearn.datasets import ?
# from sklearn.cluster import ?
#
# blob_centers = np.array([
#     [0.2, 2.3],
#     [-1.5, 2.3],
#     [-2.8, 1.8],
#     [-2.8, 2.8],
#     [-2.8, 1.3]
# ])
#
# blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])
#
# X, y = make_blobs(
#     n_samples=?,
#     centers=?,
#     cluster_std=?,
#     random_state=7
# )
#
# k = ?
#
# kmeans = KMeans(n_clusters=?, random_state=42, n_init=10)
#
# kmeans.?(?)
#
# y_pred = kmeans.?(?)
#
# print("Labels:", ?)
# print("Centroids:")
# print(?)
#
# X_new = np.array([
#     [0, 2],
#     [-3, 2],
#     [-3, 3]
# ])
#
# new_labels = kmeans.?(?)
# print("New labels:", new_labels)
#
# distances = kmeans.?(?)
# print("Distances:")
# print(distances)
#
# print("Inertia:", ?)
# Esercizio 2 — Scelta del numero ottimale di cluster
#
# Usando lo stesso dataset dell’esercizio precedente, completare il codice in modo da:
#
# provare diversi valori di k da 2 a 10;
# salvare l’inerzia per ogni valore di k;
# salvare il silhouette score per ogni valore di k;
# disegnare il grafico dell’inerzia;
# disegnare il grafico del silhouette score;
# individuare il valore di k con silhouette score massimo.
# # ESERCIZIO 2
#
# from sklearn.metrics import ?
#
# k_values = range(2, 11)
#
# inertias = []
# silhouette_scores = []
#
# for k in ?:
#     kmeans = KMeans(n_clusters=?, random_state=42, n_init=10)
#     labels = kmeans.?(?)
#
#     inertias.append(?)
#     silhouette_scores.append(silhouette_score(?, ?))
#
# plt.plot(k_values, inertias, "bo-")
# plt.xlabel("k")
# plt.ylabel("Inertia")
# plt.title("Metodo del gomito")
# plt.show()
#
# plt.plot(k_values, silhouette_scores, "bo-")
# plt.xlabel("k")
# plt.ylabel("Silhouette score")
# plt.title("Silhouette score al variare di k")
# plt.show()
#
# best_k = k_values[np.argmax(?)]
# print("Best k:", best_k)
# Esercizio 3 — Rete neurale per immagini RGB 32x32
#
# Si vuole definire una rete fully connected per immagini RGB di dimensione 32 x 32.
#
# L’input ha forma:
#
# (batch_size, 3, 32, 32)
#
# La rete deve avere:
#
# input: 3 x 32 x 32 = 3072
# hidden layer 1: 256 neuroni + ReLU
# hidden layer 2: 64 neuroni + ReLU
# output: 10 neuroni + Softmax
# # ESERCIZIO 3
#
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
#
# class RGBNetwork(nn.Module):
#
#     def __init__(self):
#         super(RGBNetwork, self).__init__()
#
#         self.fc1 = nn.Linear(?, ?)
#         self.fc2 = nn.Linear(?, ?)
#         self.fc3 = nn.Linear(?, ?)
#
#     def forward(self, x):
#
#         x = x.view(?, ?)
#
#         x = F.relu(?(x))
#         x = F.relu(?(x))
#         x = F.softmax(?(x), dim=?)
#
#         return x

# %%
# Esercizio 1

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

blob_centers = np.array([
    [0.2, 2.3],
    [-1.5, 2.3],
    [-2.8, 1.8],
    [-2.8, 2.8],
    [-2.8, 1.3]
])

blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])

X, y = make_blobs(
    n_samples=2000,
    centers=blob_centers,
    cluster_std=blob_std,
    random_state=7
)

k = 5

kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)

y_pred = kmeans.fit_predict(X)

print("Labels:")
print(y_pred)

print("Centroids:")
print(kmeans.cluster_centers_)

X_new = np.array([
    [0, 2],
    [-3, 2],
    [-3, 3]
])

new_labels = kmeans.predict(X_new)
print("New labels:", new_labels)

distances = kmeans.transform(X_new)
print("Distances:")
print(distances)

print("Inertia:", kmeans.inertia_)
'''
kmeans.fit(X) allena KMeans e trova i centroidi.

kmeans.predict(X) assegna ogni punto al cluster più vicino.

kmeans.fit_predict(X) alllena + assegna i cluster.

kmeans.transform(X) calcola le distanze euclidee dai centroidi,restituisce
una matrice in cui ogni riga è un punto e ogni colonna è un cluster,
per esempio il valore di tale matrice in posizione (0,0) vale 5,allora
vuol dire che il punto zero dista 5 dal centoide del cluster 0
'''

# %%
# Esercizio 2

from sklearn.metrics import silhouette_score

k_values = range(2, 11)

inertias = []
silhouette_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    
    labels = kmeans.fit_predict(X)
    
    inertias.append(kmeans.inertia_)
    
    silhouette_scores.append(
        silhouette_score(X, labels)
    )

plt.plot(k_values, inertias, "bo-")
plt.xlabel("k")
plt.ylabel("Inertia")
plt.title("Metodo del gomito")
plt.show()

plt.plot(k_values, silhouette_scores, "bo-")
plt.xlabel("k")
plt.ylabel("Silhouette score")
plt.title("Silhouette score al variare di k")
plt.show()

best_k = k_values[np.argmax(silhouette_scores)]
print("Best k:", best_k)

# %%
#Esercizio 3
import torch
import torch.nn as nn
import torch.nn.functional as F

class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork,self).__init__()
        self.fc1= nn.Linear(3072,256)
        self.fc2=nn.Linear(256,64)
        self.fc3 = nn.Linear(64,10)

    def forward(self,x):
        x=x.view(x.shape[0],-1)
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=F.softmax(self.fc3(x),dim=1)
        return x
